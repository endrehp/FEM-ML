# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import random
import math

import numpy as np
np.random.seed(1)
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
n_nodes = 50
n_dofs = n_nodes*2
n_elements = n_nodes-1
x = np.linspace(0, 1, n_nodes)

# %%
#Element stiffnes matrix
k = np.matrix([[12, 6, -12, 6], [6, 4, -6, 2], [-12, -6, 12, -6], [6, 2, -6, 4]])*10/12

#Element mass matrix
m = np.matrix([[156, 22, 54, -13],[22, 4, 13, -3], [54, 13, 156, -22], [-13, -3, -22, 4]] )*1/420

# %%
#Global stiffness matrix
n_dofs = n_nodes*2
K = np.zeros([n_dofs, n_dofs])
for i in range(n_elements):
    K[2*i:2*i+4,2*i:2*i+4] += k
    
#Global mass matrix
M = np.zeros([n_dofs, n_dofs])
for i in range(n_elements):
    M[2*i:2*i+4,2*i:2*i+4] += m

# %%
#Force vector
F = np.zeros(n_dofs) 
F[-2] = 10

# %%
#Initial conditions
dz0 = np.zeros(n_nodes)
dzt0 = np.zeros(n_nodes)

d0 = np.zeros(n_dofs)
dt0 = np.zeros(n_dofs)
d0[0:-1:2] = dz0

# %%
#Account for homogenous BC
F = F[2:]
K = K[2:,2:]
M = M[2:,2:]

# %%
from numpy.linalg import inv
import random

# %%
#Timestepping Theta Scheme
Theta = 1/2
d_i = d0[2:]

n_timesteps = 100
#D = np.zeros([n_nodes, n_timesteps])
#D[:,0] = dz0

dt = 1/10

Minv = inv(M)
MinvK = np.matmul(Minv, K)
Q = inv(M + Theta*dt*K)
P = (M + (Theta - 1)*dt*K)
F = np.zeros(n_dofs) 
F = F[2:]
F_i = F

r_end = []
rt_end = []
f = []

plt.figure(figsize=(16,10))

for i in range(n_timesteps):
    
    #dt_i = -np.matmul(Minv, np.matmul(K,d_i)-F)
    fi = np.random.random()*np.sin(i*dt)
    f.append(fi)
    
    F_i[-1] = fi
    
    d_i = np.matmul(Q, (np.matmul(P,d_i) + dt*F_i))
    dt_i = -np.matmul(MinvK, d_i) + np.matmul(Minv, F_i)
    
    dz = d_i[0:-1:2]
    dz = np.insert(dz,0,0)
    #dz = np.append(dz,0)
    
    r_end.append(dz[-1])
    rt_end.append(dt_i[-2])
    
    
    #if i%1000 == 0:
    plt.plot(x, dz)
    
plt.show()

# %%
plt.plot(f)

# %%
#Training data

d = 10 #number of steps in "model memory"
t = 10

X_train = np.zeros([d*3+1, n_timesteps-d])
Y_train = np.zeros([2, n_timesteps-d])

for i in range(n_timesteps-d):
    X_train[0:d+1,i] = f[t-d:t+1]
    X_train[d+1:2*d+1,i] = r_end[t-d:t]
    X_train[(2*d+1):,i] = np.array(rt_end[t-d:t])
    
    Y_train[:, i] = [r_end[t], rt_end[t]]
    t += 1

# %%
X_train[:,0]
# Out:
# array([  0.00000000e+00,   6.82907784e-04,   5.79135717e-04,
#          1.68306585e-04,   3.28130878e-03,   4.58296964e-04,
#          4.67704483e-03,   3.27106338e-03,   4.17697735e-03,
#          8.28903237e-03,   6.43522853e-03,   0.00000000e+00,
#          3.33247734e-04,   2.82407382e-04,   2.51544191e-04,
#          1.74184331e-03,   3.91107624e-04,   3.20189163e-03,
#          1.83070437e-03,   3.90511237e-03,   5.02073407e-03,
#          0.00000000e+00,  -5.44286586e-02,   6.26954044e-02,
#         -2.65594833e-02,  -2.22126824e-01,   4.47661571e-01,
#         -7.68859294e-01,   8.67216056e-01,  -9.06771866e-01,
#          5.61215746e-01])

# %%
#Neural network

train_portion = 0.8
input_dim = len(X_train[:,0])

x_train = X_train[:,0:int(n_timesteps*train_portion)]
x_test = X_train[:,0:int(n_timesteps*(1-train_portion))]
y_train = Y_train[:,0:int(n_timesteps*train_portion)]
y_test = Y_train[:,0:int(n_timesteps*train_portion)]

def baseline_model():
    model = Sequential()
    height = 50
    model.add(Dense(height, input_dim=input_dim, activation='tanh', kernel_initializer='normal'))
    model.add(Dense(height, input_dim=height, activation='tanh', kernel_initializer='normal'))
    model.add(Dense(height, input_dim=height, activation='tanh', kernel_initializer='normal'))
    model.add(Dense(2, input_dim=height, activation='linear', kernel_initializer='normal'))
    
    model.compile(loss='mse', optimizer="adam")
    return model



# Training the model
model = baseline_model()
model.fit(np.transpose(x_train), np.transpose(y_train), epochs=500, verbose = 0)

# %%
predictions = model.predict(np.transpose(x_test))

# %%
plt.plot(predictions)
# Out:
# [<matplotlib.lines.Line2D at 0x1279e4400>,
#  <matplotlib.lines.Line2D at 0x1279e45c0>]

# %%
X_train[:,0]
# Out:
# array([  0.00000000e+00,   6.00286100e-05,   2.51430600e-05,
#          1.03090828e-04,   2.97755170e-04,   3.90466885e-04,
#          4.95240898e-04,   1.07216209e-04,   3.96903023e-04,
#          1.85433704e-04,   8.30842603e-04,   0.00000000e+00,
#          2.92929715e-05,   1.22517043e-05,   6.52059038e-05,
#          1.51236342e-04,   2.27304224e-04,   3.19427908e-04,
#          1.76692557e-04,   3.74253059e-04,   2.11550045e-04,
#          0.00000000e+00,  -4.78436006e-03,   7.56443091e-03,
#         -1.34786322e-02,  -2.21562570e-03,  -4.55709934e-03,
#         -2.97361495e-03,   3.48319846e-02,  -5.67964467e-02,
#          7.24606432e-02])
